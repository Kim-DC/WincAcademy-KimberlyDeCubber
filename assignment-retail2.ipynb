# %% [markdown]
# <img src="https://static.wincacademy.nl/logos/main-logo.png" height=200px style="height: 200px"/>

# %% [markdown]
# # Assignment: Retail
#
# Congratulations! You've reached the final assignment for the course before the bonus modules. Here we'll ask you to work with a dataset from the Dutch *Centraal Bureau voor de Statistiek* (CBS, English: Statistics Netherlands). It contains monthly growth percentages for various branches of the retail sector. You'll be required to answer open questions as well as write code that handles the data and crunches numbers.
#
# *Answer open questions as though you were writing a report. Answers that are too vague, too short or too sloppy will be rejected.*

# %% [markdown]
# ## 0. Load required modules
#
# First, we need to load some modules that we're going to use. Do that in the next code cell. If you don't know yet which modules you'll use, just read on and come back here to import them later. **Don't forget to run the cell whenever you make an edit!**

# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from collections import namedtuple
import datetime
import locale
import itertools

# %% [markdown]
# ## 1. Data Preparation
# Now we need to load and parse the data. The data should be located in the same folder as this notebook (whether that's on Google Colab or your local machine). Make sure you have working file path from your notebook to the supplied `data.csv` file. Put an `x` in the checkbox below when you're ready.
#
# - [ ] *I have a working file path to the `data.csv` file.*
#
# You are now ready to proceed with reading the data into your program.
#
# ### 1.1 Read the CSV
#
# The data comes in the form of a `csv`-file. CSV stands for 'comma separated values'. Oddly enough it need not be the case that the values are *really* separated by commas. In this case, the **delimiter** - the character that separates the columns within a datapoint - is *not* a comma. It's up to you to inspect `data.csv` and find out what the delimiter is.
#
# Once you know what the delimiter is, you can use Python's `csv` module to read each of the datapoints to a dictionary. Some tips:
#
# - The module's name is `csv`.
# - You can find its documentation [here](https://docs.python.org/3/library/csv.html)
# - We suggest you use the `DictReader` class. There's an example on how to use `DictReader` in the linked documentation.
# - Instead of printing the rows (like in the example), we suggest you store all the rows as `dict`s in a `list`.
#
# **1. In the code cell below, write code that opens and reads the data. By the end of the cell, you should have a variable `data` that is a list of dictionaries that each contain a datapoint.**

# %%
import csv
def opening_csv():
    with open("retail-data.csv") as csvfile:
        global data
        data = csv.DictReader(csvfile,delimiter=";")
        print(list(data))
        #for row in data:    
        #    values = row.values()    
        #    print(values)
opening_csv()
# Out:
# [{'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2005 januari', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    73.1', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    86.4'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2005 februari', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    71.5', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    83.9'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2005 maart', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    83.0', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    96.8'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2005 april', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    79.8', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    94.1'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2005 mei', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    78.5', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    92.1'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2005 juni', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    82.3', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    96.5'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2005 juli', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    81.2', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    95.8'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2005 augustus', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    77.1', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    90.6'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2005 september', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    80.3', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    95.5'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2005 oktober', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    78.5', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    93.0'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2005 november', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    79.4', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    93.9'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2005 december', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    96.6', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '   113.7'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2006 januari', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    75.2', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    88.1'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2006 februari', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    73.5', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    85.9'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2006 maart', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    85.5', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    99.8'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2006 april', 'Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)': '    81.8', 'Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)': '    95.1'}, {'Bedrijfstakken/branches (SBI 2008)': '4711, 472 Winkels in voedingsmiddelen', 'Perioden': '2006 mei', 'Omzet ongecorrige ...

# %%
### 1.2 Parse and clean the data

You now have a list of dictionaries that each contain some data. But what data? Answer the following questions to become familiar with this dataset. It requires you to write and execute Python code (you can add code cells if you wish), and also search the web for terms you're not familiar with.

**2. What are the column names in this dataset, and what do they mean? Be specific.**

Bedrijfstakken/branches - classification of economic activities, in which sector the company is mainly active. Number correlates to type of industry the store specialises in.

Perioden - Date/period from when the data was taken

Omzet ongecorrigeerd/Indexcijfers/Waarde - Revenue in actual amounts Waarde - De ontwikkeling van de geldopbrengst van de omzet.

Omzet ongecorrigeerd/Indexcijfers/Volume - Revenue in volume. Volume - De ontwikkeling van de hoeveelheid verkochte goederen en diensten. De ontwikkeling is niet waargenomen, maar berekend. De hoeveelheid verkochte goederen en diensten in een bepaalde periode berekent het CBS door de waarde van de omzet te delen door de prijs.
*

**3. For each column, list what data type it should have (`str`, `int`, `float` or `datetime.date`).**

Branches - String
Period - Datetime
TurnoverValue - Float
TurnoverVolume - Float
*
    
**4. In the code cell below, write code that changes the column names to something more convenient for writing readable code. Be sure to choose English, correct and meaningful names.**
Bedrijfstakken/branches (SBI 2008)  - Branches
Perioden - Period
Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100) - TurnoverValue
Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100) - TurnoverVolume

# %%
def csv_to_dict(filename):
    result_list=[]
    with open(filename) as file_obj:
        reader = csv.DictReader(file_obj, delimiter=';')
        for row in reader:
            result_list.append(dict(row))
    return result_list

def ReplaceData(NewData):
    for d in NewData:
        d['Branches'] = d.pop('Bedrijfstakken/branches (SBI 2008)')
        d['Period'] = d.pop('Perioden')
        d['TurnoverValue'] = d.pop('Omzet ongecorrigeerd/Indexcijfers/Waarde (2015=100)')
        d['TurnoverVolume'] = d.pop('Omzet ongecorrigeerd/Indexcijfers/Volume (2015=100)')
    return NewData

NewData = csv_to_dict("retail-data.csv")
global NewData2
NewData2 = ReplaceData(NewData)
for d in NewData2:
    print(d)
# Out:
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2005 januari', 'TurnoverValue': '    73.1', 'TurnoverVolume': '    86.4'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2005 februari', 'TurnoverValue': '    71.5', 'TurnoverVolume': '    83.9'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2005 maart', 'TurnoverValue': '    83.0', 'TurnoverVolume': '    96.8'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2005 april', 'TurnoverValue': '    79.8', 'TurnoverVolume': '    94.1'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2005 mei', 'TurnoverValue': '    78.5', 'TurnoverVolume': '    92.1'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2005 juni', 'TurnoverValue': '    82.3', 'TurnoverVolume': '    96.5'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2005 juli', 'TurnoverValue': '    81.2', 'TurnoverVolume': '    95.8'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2005 augustus', 'TurnoverValue': '    77.1', 'TurnoverVolume': '    90.6'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2005 september', 'TurnoverValue': '    80.3', 'TurnoverVolume': '    95.5'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2005 oktober', 'TurnoverValue': '    78.5', 'TurnoverVolume': '    93.0'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2005 november', 'TurnoverValue': '    79.4', 'TurnoverVolume': '    93.9'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2005 december', 'TurnoverValue': '    96.6', 'TurnoverVolume': '   113.7'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2006 januari', 'TurnoverValue': '    75.2', 'TurnoverVolume': '    88.1'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2006 februari', 'TurnoverValue': '    73.5', 'TurnoverVolume': '    85.9'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2006 maart', 'TurnoverValue': '    85.5', 'TurnoverVolume': '    99.8'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2006 april', 'TurnoverValue': '    81.8', 'TurnoverVolume': '    95.1'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2006 mei', 'TurnoverValue': '    84.0', 'TurnoverVolume': '    97.8'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2006 juni', 'TurnoverValue': '    87.9', 'TurnoverVolume': '   102.0'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2006 juli', 'TurnoverValue': '    82.3', 'TurnoverVolume': '    95.9'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2006 augustus', 'TurnoverValue': '    82.1', 'TurnoverVolume': '    95.1'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2006 september', 'TurnoverValue': '    84.9', 'TurnoverVolume': '    98.3'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2006 oktober', 'TurnoverValue': '    79.7', 'TurnoverVolume': '    93.0'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2006 november', 'TurnoverValue': '    82.9', 'TurnoverVolume': '    96.5'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2006 december', 'TurnoverValue': '    96.6', 'TurnoverVolume': '   112.4'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2007 januari', 'TurnoverValue': '    79.0', 'TurnoverVolume': '    91.6'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2007 februari', 'TurnoverValue': '    76.9', 'TurnoverVolume': '    89.0'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2007 maart', 'TurnoverValue': '    90.8', 'TurnoverVolume': '   105.2'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2007 april', 'TurnoverValue': '    82.6', 'TurnoverVolume': '    95.3'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2007 mei', 'TurnoverValue': '    88.3', 'TurnoverVolume': '   102.4'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2007 juni', 'TurnoverValue': '    90.9', 'TurnoverVolume': '   105.1'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2007 juli', 'TurnoverValue': '    81.6', 'TurnoverVolume': '    94.4'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2007 augustus', 'TurnoverValue': '    87.3', 'TurnoverVolume': '   101.1'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2007 september', 'TurnoverValue': '    83.7', 'TurnoverVolume': '    96.8'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2007 oktober', 'TurnoverValue': '    85.5', 'TurnoverVolume': '    98.2'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2007 november', 'TurnoverValue': '    89.6', 'TurnoverVolume': '   102.0'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2007 december', 'TurnoverValue': '   101.1', 'TurnoverVolume': '   114.6'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2008 januari', 'TurnoverValue': '    84.0', 'TurnoverVolume': '    94.6'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2008 februari', 'TurnoverValue': '    87.3', 'TurnoverVolume': '    97.7'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2008 maart', 'TurnoverValue': '    92.3', 'TurnoverVolume': '   102.5'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2008 april', 'TurnoverValue': '    88.1', 'TurnoverVolume': '    97.5'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2008 mei', 'TurnoverValue': '    99.1', 'TurnoverVolume': '   109.2'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2008 juni', 'TurnoverValue': '    88.5', 'TurnoverVolume': '    97.2'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2008 juli', 'TurnoverValue': '    90.1', 'TurnoverVolume': '    98.7'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2008 augustus', 'TurnoverValue': '    91.3', 'TurnoverVolume': '   100.1'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2008 september', 'TurnoverValue': '    87.2', 'TurnoverVolume': '    95.4'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2008 oktober', 'TurnoverValue': '    94.2', 'TurnoverVolume': '   102.8'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2008 november', 'TurnoverValue': '    89.4', 'TurnoverVolume': '    96.9'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2008 december', 'TurnoverValue': '   105.8', 'TurnoverVolume': '   114.2'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2009 januari', 'TurnoverValue': '    91.1', 'TurnoverVolume': '    98.0'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2009 februari', 'TurnoverValue': '    83.3', 'TurnoverVolume': '    89.1'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2009 maart', 'TurnoverValue': '    90.0', 'TurnoverVolume': '    96.0'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2009 april', 'TurnoverValue': '    93.2', 'TurnoverVolume': '    99.4'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2009 mei', 'TurnoverValue': '    95.7', 'TurnoverVolume': '   102.3'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2009 juni', 'TurnoverValue': '    91.6', 'TurnoverVolume': '    98.3'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2009 juli', 'TurnoverValue': '    92.2', 'TurnoverVolume': '    99.7'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2009 augustus', 'TurnoverValue': '    88.7', 'TurnoverVolume': '    96.3'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2009 september', 'TurnoverValue': '    87.5', 'TurnoverVolume': '    95.3'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2009 oktober', 'TurnoverValue': '    93.6', 'TurnoverVolume': '   101.7'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2009 november', 'TurnoverValue': '    86.9', 'TurnoverVolume': '    94.6'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2009 december', 'TurnoverValue': '   106.9', 'TurnoverVolume': '   115.7'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2010 januari', 'TurnoverValue': '    87.6', 'TurnoverVolume': '    95.5'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2010 februari', 'TurnoverValue': '    82.1', 'TurnoverVolume': '    88.5'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2010 maart', 'TurnoverValue': '    92.4', 'TurnoverVolume': '    99.4'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2010 april', 'TurnoverValue': '    94.2', 'TurnoverVolume': '   101.0'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2010 mei', 'TurnoverValue': '    93.9', 'TurnoverVolume': '   100.9'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2010 juni', 'TurnoverValue': '    93.5', 'TurnoverVolume': '   100.4'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2010 juli', 'TurnoverValue': '    95.7', 'TurnoverVolume': '   102.6'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2010 augustus', 'TurnoverValue': '    87.1', 'TurnoverVolume': '    93.5'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2010 september', 'TurnoverValue': '    89.9', 'TurnoverVolume': '    96.9'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2010 oktober', 'TurnoverValue': '    92.4', 'TurnoverVolume': '    99.5'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2010 november', 'TurnoverValue': '    90.8', 'TurnoverVolume': '    97.8'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2010 december', 'TurnoverValue': '   110.0', 'TurnoverVolume': '   118.3'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2011 januari', 'TurnoverValue': '    86.0', 'TurnoverVolume': '    92.9'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2011 februari', 'TurnoverValue': '    84.0', 'TurnoverVolume': '    89.5'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2011 maart', 'TurnoverValue': '    95.0', 'TurnoverVolume': '   100.8'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2011 april', 'TurnoverValue': '    98.6', 'TurnoverVolume': '   103.7'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2011 mei', 'TurnoverValue': '    93.4', 'TurnoverVolume': '    98.0'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2011 juni', 'TurnoverValue': '    95.7', 'TurnoverVolume': '   100.2'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2011 juli', 'TurnoverValue': '    93.1', 'TurnoverVolume': '    97.5'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2011 augustus', 'TurnoverValue': '    90.8', 'TurnoverVolume': '    95.3'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2011 september', 'TurnoverValue': '    92.9', 'TurnoverVolume': '    97.8'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2011 oktober', 'TurnoverValue': '    92.4', 'TurnoverVolume': '    96.9'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2011 november', 'TurnoverValue': '    92.9', 'TurnoverVolume': '    97.3'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '2011 december', 'TurnoverValue': '   110.5', 'TurnoverVolume': '   115.4'}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': '
# {'Branches': '4711 Supermarkten', 'Period': '2005 maart', 'TurnoverValue': '    78.0', 'TurnoverVolume': '    90.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2005 april', 'TurnoverValue': '    75.0', 'TurnoverVolume': '    88.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2005 mei', 'TurnoverValue': '    73.0', 'TurnoverVolume': '    85.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2005 juni', 'TurnoverValue': '    76.0', 'TurnoverVolume': '    89.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2005 juli', 'TurnoverValue': '    75.9', 'TurnoverVolume': '    89.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2005 augustus', 'TurnoverValue': '    72.1', 'TurnoverVolume': '    84.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2005 september', 'TurnoverValue': '    74.9', 'TurnoverVolume': '    88.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2005 oktober', 'TurnoverValue': '    73.1', 'TurnoverVolume': '    86.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2005 november', 'TurnoverValue': '    74.0', 'TurnoverVolume': '    87.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2005 december', 'TurnoverValue': '    86.0', 'TurnoverVolume': '   101.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2006 januari', 'TurnoverValue': '    70.7', 'TurnoverVolume': '    82.7'}
# {'Branches': '4711 Supermarkten', 'Period': '2006 februari', 'TurnoverValue': '    68.5', 'TurnoverVolume': '    79.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2006 maart', 'TurnoverValue': '    80.6', 'TurnoverVolume': '    93.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2006 april', 'TurnoverValue': '    76.4', 'TurnoverVolume': '    88.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2006 mei', 'TurnoverValue': '    78.8', 'TurnoverVolume': '    91.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2006 juni', 'TurnoverValue': '    81.9', 'TurnoverVolume': '    94.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2006 juli', 'TurnoverValue': '    77.2', 'TurnoverVolume': '    89.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2006 augustus', 'TurnoverValue': '    77.6', 'TurnoverVolume': '    89.7'}
# {'Branches': '4711 Supermarkten', 'Period': '2006 september', 'TurnoverValue': '    79.7', 'TurnoverVolume': '    92.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2006 oktober', 'TurnoverValue': '    74.3', 'TurnoverVolume': '    86.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2006 november', 'TurnoverValue': '    77.2', 'TurnoverVolume': '    89.7'}
# {'Branches': '4711 Supermarkten', 'Period': '2006 december', 'TurnoverValue': '    86.2', 'TurnoverVolume': '   100.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2007 januari', 'TurnoverValue': '    74.8', 'TurnoverVolume': '    86.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2007 februari', 'TurnoverValue': '    72.4', 'TurnoverVolume': '    83.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2007 maart', 'TurnoverValue': '    86.4', 'TurnoverVolume': '    99.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2007 april', 'TurnoverValue': '    77.6', 'TurnoverVolume': '    89.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2007 mei', 'TurnoverValue': '    83.6', 'TurnoverVolume': '    96.7'}
# {'Branches': '4711 Supermarkten', 'Period': '2007 juni', 'TurnoverValue': '    85.2', 'TurnoverVolume': '    98.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2007 juli', 'TurnoverValue': '    76.8', 'TurnoverVolume': '    88.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2007 augustus', 'TurnoverValue': '    83.1', 'TurnoverVolume': '    96.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2007 september', 'TurnoverValue': '    78.8', 'TurnoverVolume': '    90.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2007 oktober', 'TurnoverValue': '    80.8', 'TurnoverVolume': '    92.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2007 november', 'TurnoverValue': '    84.8', 'TurnoverVolume': '    96.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2007 december', 'TurnoverValue': '    91.5', 'TurnoverVolume': '   103.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2008 januari', 'TurnoverValue': '    80.5', 'TurnoverVolume': '    90.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2008 februari', 'TurnoverValue': '    84.1', 'TurnoverVolume': '    93.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2008 maart', 'TurnoverValue': '    88.6', 'TurnoverVolume': '    98.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2008 april', 'TurnoverValue': '    84.3', 'TurnoverVolume': '    92.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2008 mei', 'TurnoverValue': '    95.9', 'TurnoverVolume': '   105.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2008 juni', 'TurnoverValue': '    84.3', 'TurnoverVolume': '    92.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2008 juli', 'TurnoverValue': '    87.0', 'TurnoverVolume': '    94.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2008 augustus', 'TurnoverValue': '    88.2', 'TurnoverVolume': '    96.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2008 september', 'TurnoverValue': '    83.4', 'TurnoverVolume': '    91.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2008 oktober', 'TurnoverValue': '    91.0', 'TurnoverVolume': '    98.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2008 november', 'TurnoverValue': '    85.7', 'TurnoverVolume': '    92.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2008 december', 'TurnoverValue': '    97.6', 'TurnoverVolume': '   105.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2009 januari', 'TurnoverValue': '    88.8', 'TurnoverVolume': '    95.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2009 februari', 'TurnoverValue': '    80.9', 'TurnoverVolume': '    86.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2009 maart', 'TurnoverValue': '    87.7', 'TurnoverVolume': '    93.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2009 april', 'TurnoverValue': '    90.7', 'TurnoverVolume': '    96.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2009 mei', 'TurnoverValue': '    92.8', 'TurnoverVolume': '    98.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2009 juni', 'TurnoverValue': '    88.4', 'TurnoverVolume': '    94.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2009 juli', 'TurnoverValue': '    89.5', 'TurnoverVolume': '    96.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2009 augustus', 'TurnoverValue': '    86.4', 'TurnoverVolume': '    93.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2009 september', 'TurnoverValue': '    84.6', 'TurnoverVolume': '    91.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2009 oktober', 'TurnoverValue': '    91.1', 'TurnoverVolume': '    98.7'}
# {'Branches': '4711 Supermarkten', 'Period': '2009 november', 'TurnoverValue': '    83.9', 'TurnoverVolume': '    91.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2009 december', 'TurnoverValue': '   100.1', 'TurnoverVolume': '   108.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2010 januari', 'TurnoverValue': '    86.6', 'TurnoverVolume': '    94.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2010 februari', 'TurnoverValue': '    80.5', 'TurnoverVolume': '    86.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2010 maart', 'TurnoverValue': '    90.5', 'TurnoverVolume': '    97.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2010 april', 'TurnoverValue': '    92.4', 'TurnoverVolume': '    98.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2010 mei', 'TurnoverValue': '    92.3', 'TurnoverVolume': '    98.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2010 juni', 'TurnoverValue': '    90.8', 'TurnoverVolume': '    97.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2010 juli', 'TurnoverValue': '    94.1', 'TurnoverVolume': '   100.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2010 augustus', 'TurnoverValue': '    85.7', 'TurnoverVolume': '    91.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2010 september', 'TurnoverValue': '    87.9', 'TurnoverVolume': '    94.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2010 oktober', 'TurnoverValue': '    90.6', 'TurnoverVolume': '    97.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2010 november', 'TurnoverValue': '    88.5', 'TurnoverVolume': '    95.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2010 december', 'TurnoverValue': '   104.0', 'TurnoverVolume': '   111.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2011 januari', 'TurnoverValue': '    85.3', 'TurnoverVolume': '    92.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2011 februari', 'TurnoverValue': '    82.7', 'TurnoverVolume': '    88.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2011 maart', 'TurnoverValue': '    94.0', 'TurnoverVolume': '    99.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2011 april', 'TurnoverValue': '    97.3', 'TurnoverVolume': '   102.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2011 mei', 'TurnoverValue': '    91.8', 'TurnoverVolume': '    96.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2011 juni', 'TurnoverValue': '    94.1', 'TurnoverVolume': '    98.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2011 juli', 'TurnoverValue': '    92.1', 'TurnoverVolume': '    96.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2011 augustus', 'TurnoverValue': '    90.3', 'TurnoverVolume': '    94.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2011 september', 'TurnoverValue': '    91.7', 'TurnoverVolume': '    96.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2011 oktober', 'TurnoverValue': '    91.4', 'TurnoverVolume': '    95.7'}
# {'Branches': '4711 Supermarkten', 'Period': '2011 november', 'TurnoverValue': '    91.2', 'TurnoverVolume': '    95.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2011 december', 'TurnoverValue': '   104.7', 'TurnoverVolume': '   109.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2012 januari', 'TurnoverValue': '    88.0', 'TurnoverVolume': '    92.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2012 februari', 'TurnoverValue': '    88.2', 'TurnoverVolume': '    91.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2012 maart', 'TurnoverValue': '    98.6', 'TurnoverVolume': '   101.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2012 april', 'TurnoverValue': '    91.7', 'TurnoverVolume': '    94.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2012 mei', 'TurnoverValue': '    98.3', 'TurnoverVolume': '   101.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2012 juni', 'TurnoverValue': '    98.2', 'TurnoverVolume': '   100.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2012 juli', 'TurnoverValue': '    91.1', 'TurnoverVolume': '    93.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2012 augustus', 'TurnoverValue': '    97.0', 'TurnoverVolume': '   100.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2012 september', 'TurnoverValue': '    91.9', 'TurnoverVolume': '    94.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2012 oktober', 'TurnoverValue': '    94.0', 'TurnoverVolume': '    96.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2012 november', 'TurnoverValue': '    95.4', 'TurnoverVolume': '    97.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2012 december', 'TurnoverValue': '   105.0', 'TurnoverVolume': '   106.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2013 januari', 'TurnoverValue': '    93.3', 'TurnoverVolume': '    94.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2013 februari', 'TurnoverValue': '    86.8', 'TurnoverVolume': '    86.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2013 maart', 'TurnoverValue': '   102.7', 'TurnoverVolume': '   102.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2013 april', 'TurnoverValue': '    92.5', 'TurnoverVolume': '    92.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2013 mei', 'TurnoverValue': '   103.0', 'TurnoverVolume': '   102.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2013 juni', 'TurnoverValue': '    96.4', 'TurnoverVolume': '    95.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2013 juli', 'TurnoverValue': '    97.1', 'TurnoverVolume': '    95.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2013 augustus', 'TurnoverValue': '   100.1', 'TurnoverVolume': '    99.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2013 september', 'TurnoverValue': '    89.8', 'TurnoverVolume': '    90.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2013  oktober', 'TurnoverValue': '    96.0', 'TurnoverVolume': '    96.7'}
# {'Branches': '4711 Supermarkten', 'Period': '2013  november', 'TurnoverValue': '    96.2', 'TurnoverVolume': '    97.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2013 december ', 'TurnoverValue': '   103.7', 'TurnoverVolume': '   103.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2014 januari', 'TurnoverValue': '    95.5', 'TurnoverVolume': '    96.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2014 februari', 'TurnoverValue': '    87.5', 'TurnoverVolume': '    87.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2014 maart', 'TurnoverValue': '    98.1', 'TurnoverVolume': '    98.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2014 april', 'TurnoverValue': '    98.8', 'TurnoverVolume': '    98.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2014 mei', 'TurnoverValue': '   104.8', 'TurnoverVolume': '   104.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2014 juni', 'TurnoverValue': '    97.5', 'TurnoverVolume': '    97.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2014 juli', 'TurnoverValue': '    99.7', 'TurnoverVolume': '    99.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2014 augustus', 'TurnoverValue': '    97.8', 'TurnoverVolume': '    98.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2014 september', 'TurnoverValue': '    93.5', 'TurnoverVolume': '    94.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2014 oktober', 'TurnoverValue': '   100.1', 'TurnoverVolume': '   100.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2014 november', 'TurnoverValue': '    95.8', 'TurnoverVolume': '    96.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2014 december', 'TurnoverValue': '   108.4', 'TurnoverVolume': '   109.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2015 januari', 'TurnoverValue': '    99.0', 'TurnoverVolume': '   100.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2015 februari', 'TurnoverValue': '    89.7', 'TurnoverVolume': '    89.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2015 maart', 'TurnoverValue': '    98.0', 'TurnoverVolume': '    98.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2015 april', 'TurnoverValue': '   101.0', 'TurnoverVolume': '   101.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2015 mei', 'TurnoverValue': '   104.4', 'TurnoverVolume': '   104.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2015 juni', 'TurnoverValue': '   101.0', 'TurnoverVolume': '   101.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2015 juli', 'TurnoverValue': '   101.9', 'TurnoverVolume': '   101.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2015 augustus', 'TurnoverValue': '    98.9', 'TurnoverVolume': '    98.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2015 september', 'TurnoverValue': '    96.8', 'TurnoverVolume': '    96.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2015 oktober', 'TurnoverValue': '   103.4', 'TurnoverVolume': '   103.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2015 november', 'TurnoverValue': '    95.1', 'TurnoverVolume': '    95.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2015 december', 'TurnoverValue': '   110.9', 'TurnoverVolume': '   110.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2016 januari', 'TurnoverValue': '    97.0', 'TurnoverVolume': '    97.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2016 februari', 'TurnoverValue': '    93.0', 'TurnoverVolume': '    92.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2016 maart', 'TurnoverValue': '   105.5', 'TurnoverVolume': '   104.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2016 april', 'TurnoverValue': '   101.8', 'TurnoverVolume': '   100.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2016 mei', 'TurnoverValue': '   103.0', 'TurnoverVolume': '   101.6'}
# {'Branches': '4711 Supermarkten', 'Period': '2016 juni', 'TurnoverValue': '   103.8', 'TurnoverVolume': '   102.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2016 juli', 'TurnoverValue': '   102.5', 'TurnoverVolume': '   101.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2016 augustus', 'TurnoverValue': '   100.5', 'TurnoverVolume': '    99.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2016 september', 'TurnoverValue': '   101.8', 'TurnoverVolume': '   101.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2016 oktober', 'TurnoverValue': '   101.0', 'TurnoverVolume': '   100.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2016 november', 'TurnoverValue': '   100.2', 'TurnoverVolume': '    99.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2016 december', 'TurnoverValue': '   115.0', 'TurnoverVolume': '   113.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2017 januari', 'TurnoverValue': '    98.1', 'TurnoverVolume': '    97.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2017 februari', 'TurnoverValue': '    93.9', 'TurnoverVolume': '    91.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2017 maart', 'TurnoverValue': '   107.4', 'TurnoverVolume': '   104.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2017 april', 'TurnoverValue': '   104.6', 'TurnoverVolume': '   102.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2017 mei', 'TurnoverValue': '   108.5', 'TurnoverVolume': '   105.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2017 juni', 'TurnoverValue': '   110.0', 'TurnoverVolume': '   106.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2017 juli', 'TurnoverValue': '   103.8', 'TurnoverVolume': '   100.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2017 augustus', 'TurnoverValue': '   104.5', 'TurnoverVolume': '   100.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2017 september', 'TurnoverValue': '   105.0', 'TurnoverVolume': '   101.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2017 oktober', 'TurnoverValue': '   103.2', 'TurnoverVolume': '    99.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2017 november', 'TurnoverValue': '   105.4', 'TurnoverVolume': '   102.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2017 december', 'TurnoverValue': '   117.8', 'TurnoverVolume': '   113.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2018 januari', 'TurnoverValue': '   101.8', 'TurnoverVolume': '    98.7'}
# {'Branches': '4711 Supermarkten', 'Period': '2018 februari', 'TurnoverValue': '    96.9', 'TurnoverVolume': '    93.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2018 maart', 'TurnoverValue': '   113.9', 'TurnoverVolume': '   110.2'}
# {'Branches': '4711 Supermarkten', 'Period': '2018 april', 'TurnoverValue': '   105.6', 'TurnoverVolume': '   101.7'}
# {'Branches': '4711 Supermarkten', 'Period': '2018 mei', 'TurnoverValue': '   115.1', 'TurnoverVolume': '   110.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2018 juni', 'TurnoverValue': '   114.9', 'TurnoverVolume': '   110.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2018 juli', 'TurnoverValue': '   108.2', 'TurnoverVolume': '   103.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2018 augustus', 'TurnoverValue': '   111.0', 'TurnoverVolume': '   106.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2018 september', 'TurnoverValue': '   105.5', 'TurnoverVolume': '   101.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2018 oktober', 'TurnoverValue': '   108.7', 'TurnoverVolume': '   104.1'}
# {'Branches': '4711 Supermarkten', 'Period': '2018 november', 'TurnoverValue': '   109.9', 'TurnoverVolume': '   104.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2018 december', 'TurnoverValue': '   120.0', 'TurnoverVolume': '   114.5'}
# {'Branches': '4711 Supermarkten', 'Period': '2019 januari', 'TurnoverValue': '   105.5', 'TurnoverVolume': '   101.9'}
# {'Branches': '4711 Supermarkten', 'Period': '2019 februari', 'TurnoverValue': '    98.4', 'TurnoverVolume': '    94.0'}
# {'Branches': '4711 Supermarkten', 'Period': '2019 maart', 'TurnoverValue': '   113.0', 'TurnoverVolume': '   108.3'}
# {'Branches': '4711 Supermarkten', 'Period': '2019 april', 'TurnoverValue': '   110.5', 'TurnoverVolume': '   105.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2019 mei', 'TurnoverValue': '   116.8', 'TurnoverVolume': '   111.4'}
# {'Branches': '4711 Supermarkten', 'Period': '2019 juni', 'TurnoverValue': '   112.8', 'TurnoverVolume': '   106.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2019 juli', 'TurnoverValue': '   112.3', 'TurnoverVolume': '   105.7'}
# {'Branches': '4711 Supermarkten', 'Period': '2019 augustus', 'TurnoverValue': '   114.9', 'TurnoverVolume': '   107.8'}
# {'Branches': '4711 Supermarkten', 'Period': '2019 september', 'TurnoverValue': '   105.1', 'TurnoverVolume': '    99.0'}
# ...
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2011 juli', 'TurnoverValue': '    62.8', 'TurnoverVolume': '    63.4'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2011 augustus', 'TurnoverValue': '    64.7', 'TurnoverVolume': '    64.9'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2011 september', 'TurnoverValue': '    65.4', 'TurnoverVolume': '    63.9'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2011 oktober', 'TurnoverValue': '    63.0', 'TurnoverVolume': '    61.5'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2011 november', 'TurnoverValue': '    74.1', 'TurnoverVolume': '    72.5'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2011 december', 'TurnoverValue': '    73.5', 'TurnoverVolume': '    73.0'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2012 januari', 'TurnoverValue': '    72.7', 'TurnoverVolume': '    73.4'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2012 februari', 'TurnoverValue': '    65.6', 'TurnoverVolume': '    65.5'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2012 maart', 'TurnoverValue': '    68.5', 'TurnoverVolume': '    65.8'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2012 april', 'TurnoverValue': '    65.9', 'TurnoverVolume': '    63.3'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2012 mei', 'TurnoverValue': '    70.5', 'TurnoverVolume': '    68.1'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2012 juni', 'TurnoverValue': '    70.1', 'TurnoverVolume': '    68.8'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2012 juli', 'TurnoverValue': '    70.4', 'TurnoverVolume': '    69.9'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2012 augustus', 'TurnoverValue': '    66.4', 'TurnoverVolume': '    65.8'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2012 september', 'TurnoverValue': '    70.4', 'TurnoverVolume': '    68.2'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2012 oktober', 'TurnoverValue': '    73.8', 'TurnoverVolume': '    71.6'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2012 november', 'TurnoverValue': '    78.2', 'TurnoverVolume': '    75.9'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2012 december', 'TurnoverValue': '    79.2', 'TurnoverVolume': '    77.9'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2013 januari', 'TurnoverValue': '    76.8', 'TurnoverVolume': '    76.7'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2013 februari', 'TurnoverValue': '    67.8', 'TurnoverVolume': '    67.0'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2013 maart', 'TurnoverValue': '    72.4', 'TurnoverVolume': '    69.0'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2013 april', 'TurnoverValue': '    73.9', 'TurnoverVolume': '    70.4'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2013 mei', 'TurnoverValue': '    77.7', 'TurnoverVolume': '    74.1'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2013 juni', 'TurnoverValue': '    75.8', 'TurnoverVolume': '    73.2'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2013 juli', 'TurnoverValue': '    80.1', 'TurnoverVolume': '    78.9'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2013 augustus', 'TurnoverValue': '    73.9', 'TurnoverVolume': '    72.7'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2013 september', 'TurnoverValue': '    78.5', 'TurnoverVolume': '    76.1'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2013  oktober', 'TurnoverValue': '    81.6', 'TurnoverVolume': '    79.4'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2013  november', 'TurnoverValue': '    84.2', 'TurnoverVolume': '    82.3'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2013 december ', 'TurnoverValue': '    95.5', 'TurnoverVolume': '    94.4'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2014 januari', 'TurnoverValue': '    83.6', 'TurnoverVolume': '    83.9'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2014 februari', 'TurnoverValue': '    74.7', 'TurnoverVolume': '    74.5'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2014 maart', 'TurnoverValue': '    80.8', 'TurnoverVolume': '    78.0'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2014 april', 'TurnoverValue': '    83.8', 'TurnoverVolume': '    81.1'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2014 mei', 'TurnoverValue': '    84.9', 'TurnoverVolume': '    82.5'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2014 juni', 'TurnoverValue': '    83.7', 'TurnoverVolume': '    82.3'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2014 juli', 'TurnoverValue': '    86.3', 'TurnoverVolume': '    87.1'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2014 augustus', 'TurnoverValue': '    82.9', 'TurnoverVolume': '    83.7'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2014 september', 'TurnoverValue': '    87.0', 'TurnoverVolume': '    86.3'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2014 oktober', 'TurnoverValue': '    90.5', 'TurnoverVolume': '    89.9'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2014 november', 'TurnoverValue': '    93.5', 'TurnoverVolume': '    93.5'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2014 december', 'TurnoverValue': '   109.7', 'TurnoverVolume': '   110.8'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2015 januari', 'TurnoverValue': '    91.8', 'TurnoverVolume': '    94.9'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2015 februari', 'TurnoverValue': '    82.6', 'TurnoverVolume': '    84.6'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2015 maart', 'TurnoverValue': '    93.3', 'TurnoverVolume': '    92.4'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2015 april', 'TurnoverValue': '    93.5', 'TurnoverVolume': '    92.2'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2015 mei', 'TurnoverValue': '    92.1', 'TurnoverVolume': '    90.8'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2015 juni', 'TurnoverValue': '    99.9', 'TurnoverVolume': '    99.0'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2015 juli', 'TurnoverValue': '    99.9', 'TurnoverVolume': '   100.8'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2015 augustus', 'TurnoverValue': '    94.3', 'TurnoverVolume': '    95.2'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2015 september', 'TurnoverValue': '   103.7', 'TurnoverVolume': '   102.8'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2015 oktober', 'TurnoverValue': '   103.7', 'TurnoverVolume': '   102.3'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2015 november', 'TurnoverValue': '   114.1', 'TurnoverVolume': '   113.2'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2015 december', 'TurnoverValue': '   131.2', 'TurnoverVolume': '   131.6'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2016 januari', 'TurnoverValue': '   107.8', 'TurnoverVolume': '   109.7'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2016 februari', 'TurnoverValue': '   100.6', 'TurnoverVolume': '   100.8'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2016 maart', 'TurnoverValue': '   112.4', 'TurnoverVolume': '   109.3'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2016 april', 'TurnoverValue': '   109.4', 'TurnoverVolume': '   106.8'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2016 mei', 'TurnoverValue': '   112.0', 'TurnoverVolume': '   109.6'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2016 juni', 'TurnoverValue': '   119.2', 'TurnoverVolume': '   118.3'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2016 juli', 'TurnoverValue': '   115.4', 'TurnoverVolume': '   116.8'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2016 augustus', 'TurnoverValue': '   113.9', 'TurnoverVolume': '   114.5'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2016 september', 'TurnoverValue': '   116.5', 'TurnoverVolume': '   115.7'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2016 oktober', 'TurnoverValue': '   121.4', 'TurnoverVolume': '   119.9'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '
}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2020 januari*', 'TurnoverValue': '   185.2', 'TurnoverVolume': '   184.1'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2020 februari*', 'TurnoverValue': '   167.6', 'TurnoverVolume': '   165.0'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2020 maart*', 'TurnoverValue': '   202.6', 'TurnoverVolume': '   197.2'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2020 april*', 'TurnoverValue': '   228.8', 'TurnoverVolume': '   221.4'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2020 mei*', 'TurnoverValue': '   236.9', 'TurnoverVolume': '   228.9'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2020 juni*', 'TurnoverValue': '   232.0', 'TurnoverVolume': '   224.4'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2020 juli*', 'TurnoverValue': '   220.4', 'TurnoverVolume': '   215.3'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2020 augustus*', 'TurnoverValue': '   212.7', 'TurnoverVolume': '   208.6'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2020 september*', 'TurnoverValue': '   220.3', 'TurnoverVolume': '   212.5'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2020 oktober*', 'TurnoverValue': '   242.8', 'TurnoverVolume': '   231.0'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2020 november*', 'TurnoverValue': '   284.3', 'TurnoverVolume': '   271.6'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2020 december*', 'TurnoverValue': '   300.0', 'TurnoverVolume': '   288.2'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2021 januari*', 'TurnoverValue': '   276.4', 'TurnoverVolume': '   269.3'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2021 februari*', 'TurnoverValue': '   255.7', 'TurnoverVolume': '   246.4'}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': '2021 maart*', 'TurnoverValue': '   297.3', 'TurnoverVolume': '   285.8'}

# %% [markdown]
# **5. In the code cell below, write code that casts all the data to the right type.**
#
# Tips:
# - If you overwite your data, running the casting operation you're about to implement more than once might result in errors. In that case you can opt not to reuse a variable or restart and rerun your notebook for every retry.
# - The data is in Dutch. For some columns this does not matter, but for one in particular it makes parsing it a little bit harder. There is a way to handle this in a few lines of code. You'll need Python's `locale` module for this, as well as the special string `'nl_NL.UTF-8'`. If you're not sure how to use this information after searching the web for a while, it's OK to take the long way around and write custom code to handle the Dutch words.
# - The parsing script is bound to run into errors. **Do not modify the data file on disk.** Carefully read the error, examine why it works on most values and crashes on some others, and apply a fix in your code! We'll give you some tips:
#     - A handful of values in the `Perioden`-column might cause an error due to an unexpected character. You can safely ignore that character.
#     - Handle missing numerical values by replacing them with `-1.`. Be sure to maintain the correct datatype for that column!

# %%
# Your code here.
global NewData2
import pandas

#newData3 = {NewData2}
#pd.DataFrame([newData3])
#df = pd.DataFrame(list(newData3),converters={"Branches":str}, {"Period":datetime}, {"TurnoverValue":float}, {"TurnoverVolume":float})

locale.setlocale(locale.LC_ALL, "nl_NL")
for d in NewData2:
    #print(d)
    try:
        replace_turnoverValue = d["TurnoverValue"]
        if replace_turnoverValue == ('       .'):
            replace_turnoverValue = '-1'
        else:
            replace_turnoverValue = replace_turnoverValue.strip()
        replace_turnoverVolume = d["TurnoverVolume"]
        if replace_turnoverVolume == ('       .'):
            replace_turnoverVolume = '-1'
        else:
            replace_turnoverVolume = replace_turnoverVolume.strip()
        d["TurnoverValue"] = float(replace_turnoverValue)
        d["TurnoverVolume"] = float(replace_turnoverVolume)
        replace_date = d["Period"]
        replace_date = replace_date.replace("*",'')
        replace_date = replace_date.strip()
        replace_date = datetime.datetime.strptime(replace_date, '%Y %B')
       # replace_date = datetime.datetime.strftime(replace_date, '%Y %B')
        d["Period"] = replace_date
        print(d)
        
    except:
        print('error')
        print(d)
        print('above here')
        print(OSError)

#def overWrite(NewData2):
#    for row in NewData2:
#        row ['Branches'] = str(row['Branches'])
#        row ['Period'] = datetime(row['Period'])
#        row ['TurnoverValue'] = float(row['TurnoverValue'])
#        row ['TurnoverVolume'] = float(row['TurnoverVolume'])
#        yield row
#    print(row)
# Out:
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': datetime.datetime(

# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': datetime.datetime(2021, 2, 1, 0, 0), 'TurnoverValue': 109.3, 'TurnoverVolume': 101.3}
# {'Branches': '4711, 472 Winkels in voedingsmiddelen', 'Period': datetime.datetime(2021, 3, 1, 0, 0), 'TurnoverValue': 120.7, 'TurnoverVolume': 112.4}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2005, 1, 1, 0, 0), 'TurnoverValue': 68.4, 'TurnoverVolume': 80.8}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2005, 2, 1, 0, 0), 'TurnoverValue': 66.8, 'TurnoverVolume': 78.3}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2005, 3, 1, 0, 0), 'TurnoverValue': 78.0, 'TurnoverVolume': 90.9}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2005, 4, 1, 0, 0), 'TurnoverValue': 75.0, 'TurnoverVolume': 88.3}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2005, 5, 1, 0, 0), 'TurnoverValue': 73.0, 'TurnoverVolume': 85.6}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2005, 6, 1, 0, 0), 'TurnoverValue': 76.0, 'TurnoverVolume': 89.1}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2005, 7, 1, 0, 0), 'TurnoverValue': 75.9, 'TurnoverVolume': 89.3}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2005, 8, 1, 0, 0), 'TurnoverValue': 72.1, 'TurnoverVolume': 84.6}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2005, 9, 1, 0, 0), 'TurnoverValue': 74.9, 'TurnoverVolume': 88.9}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2005, 10, 1, 0, 0), 'TurnoverValue': 73.1, 'TurnoverVolume': 86.6}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2005, 11, 1, 0, 0), 'TurnoverValue': 74.0, 'TurnoverVolume': 87.4}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2005, 12, 1, 0, 0), 'TurnoverValue': 86.0, 'TurnoverVolume': 101.3}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2006, 1, 1, 0, 0), 'TurnoverValue': 70.7, 'TurnoverVolume': 82.7}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2006, 2, 1, 0, 0), 'TurnoverValue': 68.5, 'TurnoverVolume': 79.9}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2006, 3, 1, 0, 0), 'TurnoverValue': 80.6, 'TurnoverVolume': 93.8}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2006, 4, 1, 0, 0), 'TurnoverValue': 76.4, 'TurnoverVolume': 88.6}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2006, 5, 1, 0, 0), 'TurnoverValue': 78.8, 'TurnoverVolume': 91.5}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2006, 6, 1, 0, 0), 'TurnoverValue': 81.9, 'TurnoverVolume': 94.8}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2006, 7, 1, 0, 0), 'TurnoverValue': 77.2, 'TurnoverVolume': 89.8}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2006, 8, 1, 0, 0), 'TurnoverValue': 77.6, 'TurnoverVolume': 89.7}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2006, 9, 1, 0, 0), 'TurnoverValue': 79.7, 'TurnoverVolume': 92.1}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2006, 10, 1, 0, 0), 'TurnoverValue': 74.3, 'TurnoverVolume': 86.5}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2006, 11, 1, 0, 0), 'TurnoverValue': 77.2, 'TurnoverVolume': 89.7}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2006, 12, 1, 0, 0), 'TurnoverValue': 86.2, 'TurnoverVolume': 100.1}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2007, 1, 1, 0, 0), 'TurnoverValue': 74.8, 'TurnoverVolume': 86.5}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2007, 2, 1, 0, 0), 'TurnoverValue': 72.4, 'TurnoverVolume': 83.5}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2007, 3, 1, 0, 0), 'TurnoverValue': 86.4, 'TurnoverVolume': 99.8}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2007, 4, 1, 0, 0), 'TurnoverValue': 77.6, 'TurnoverVolume': 89.3}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2007, 5, 1, 0, 0), 'TurnoverValue': 83.6, 'TurnoverVolume': 96.7}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(2007, 6, 1, 0, 0), 'TurnoverValue': 85.2, 'TurnoverVolume': 98.4}
# {'Branches': '4711 Supermarkten', 'Period': datetime.datetime(

# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2018, 11, 1, 0, 0), 'TurnoverValue': 187.0, 'TurnoverVolume': 184.6}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2018, 12, 1, 0, 0), 'TurnoverValue': 187.8, 'TurnoverVolume': 186.3}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2019, 1, 1, 0, 0), 'TurnoverValue': 165.5, 'TurnoverVolume': 167.0}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2019, 2, 1, 0, 0), 'TurnoverValue': 146.6, 'TurnoverVolume': 146.2}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2019, 3, 1, 0, 0), 'TurnoverValue': 166.6, 'TurnoverVolume': 164.4}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2019, 4, 1, 0, 0), 'TurnoverValue': 163.8, 'TurnoverVolume': 162.0}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2019, 5, 1, 0, 0), 'TurnoverValue': 177.5, 'TurnoverVolume': 175.7}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2019, 6, 1, 0, 0), 'TurnoverValue': 171.9, 'TurnoverVolume': 171.0}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2019, 7, 1, 0, 0), 'TurnoverValue': 178.5, 'TurnoverVolume': 179.2}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2019, 8, 1, 0, 0), 'TurnoverValue': 167.0, 'TurnoverVolume': 165.8}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2019, 9, 1, 0, 0), 'TurnoverValue': 175.4, 'TurnoverVolume': 173.2}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2019, 10, 1, 0, 0), 'TurnoverValue': 179.6, 'TurnoverVolume': 176.0}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2019, 11, 1, 0, 0), 'TurnoverValue': 207.1, 'TurnoverVolume': 201.4}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2019, 12, 1, 0, 0), 'TurnoverValue': 223.9, 'TurnoverVolume': 219.1}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2020, 1, 1, 0, 0), 'TurnoverValue': 185.2, 'TurnoverVolume': 184.1}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2020, 2, 1, 0, 0), 'TurnoverValue': 167.6, 'TurnoverVolume': 165.0}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2020, 3, 1, 0, 0), 'TurnoverValue': 202.6, 'TurnoverVolume': 197.2}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2020, 4, 1, 0, 0), 'TurnoverValue': 228.8, 'TurnoverVolume': 221.4}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2020, 5, 1, 0, 0), 'TurnoverValue': 236.9, 'TurnoverVolume': 228.9}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2020, 6, 1, 0, 0), 'TurnoverValue': 232.0, 'TurnoverVolume': 224.4}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2020, 7, 1, 0, 0), 'TurnoverValue': 220.4, 'TurnoverVolume': 215.3}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2020, 8, 1, 0, 0), 'TurnoverValue': 212.7, 'TurnoverVolume': 208.6}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2020, 9, 1, 0, 0), 'TurnoverValue': 220.3, 'TurnoverVolume': 212.5}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2020, 10, 1, 0, 0), 'TurnoverValue': 242.8, 'TurnoverVolume': 231.0}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2020, 11, 1, 0, 0), 'TurnoverValue': 284.3, 'TurnoverVolume': 271.6}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2020, 12, 1, 0, 0), 'TurnoverValue': 300.0, 'TurnoverVolume': 288.2}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2021, 1, 1, 0, 0), 'TurnoverValue': 276.4, 'TurnoverVolume': 269.3}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2021, 2, 1, 0, 0), 'TurnoverValue': 255.7, 'TurnoverVolume': 246.4}
# {'Branches': '4791 Postorderbedrijven, webwinkels', 'Period': datetime.datetime(2021, 3, 1, 0, 0), 'TurnoverValue': 297.3, 'TurnoverVolume': 285.8}

# %%
## 2. Data Exploration

You are now ready to explore the data.

**6. In the code cell below, print the following metadata. Format the printed text in a nice and tidy way. Put an `x` in the checkboxes when you've succeeded.**

- [x] **The number of datapoints in the dataset.**
- [x] **The number of unique branches of the retail sector the data covers.**
- [x] **The first month covered by the data.**
- [x] **The last month covered by the data.**

# %%
# Your code here.

branch_set = set()
date_set = set()
#total_set = set()
for row in NewData2:
    branch_set.add(row['Branches'])
    date_set.add(row["Period"])
print('Unique branches ', len(branch_set))
print('first ', min(date_set))
print("Last ", max(date_set))
print('Datapoints' , len(NewData2))
# Out:
# Unique branches  16
# first  2005-01-01 00:00:00
# Last  2021-03-01 00:00:00
# Datapoints 3120

# %% [markdown]
# **7. In the code cell below, extract the revenue numbers for the following two sectors and put them in a list named exactly as indicated. Also create a list that contains all the months in ascending order. Run the cell after it to see a plot of the numbers if you did it correctly.**
#
# - [x] Months in ascending order $\Longrightarrow$ `months`
# - [x] Clothing stores $\Longrightarrow$  `clothing_stores_revenue`
#     - Tip: the Dutch word for *'clothing'* is *'kleding'*
# - [x] Mail order companies and web shops $\Longrightarrow$ `mail_order_revenue`
#     - Tip: the Dutch term for *'mail order companies'* is *'postorderbedrijven'*

# %%
# Your code here.

months = list(date_set)
months.sort()

clothing_stores = list()
mail_order = list()

for row in NewData2:
  if row['Branches'] == '4771 Winkels in kleding':
    clothing_stores.append(row)
  if row['Branches'] == '4791 Postorderbedrijven, webwinkels':
    mail_order.append(row)

clothing_stores_revenue = list()
mail_order_revenue = list()

for month in months:
  for row in clothing_stores:
    if row['Period'] == month:
      clothing_stores_revenue.append(row['TurnoverValue'])
      break
  else:
    clothing_stores_revenue.append(-1)

  for row in mail_order:
    if row['Period'] == month:
      mail_order_revenue.append(row['TurnoverValue'])
      break
  else:
    mail_order_revenue.append(-1)

print(list(clothing_stores_revenue))
print(list(mail_order_revenue))
# Out:
# [84.1, 73.1, 106.7, 113.3, 104.9, 112.7, 96.9, 93.1, 114.4, 129.3, 107.1, 131.3, 90.0, 77.9, 105.8, 119.0, 122.8, 116.2, 99.6, 109.8, 117.7, 132.0, 115.9, 136.4, 94.3, 85.2, 123.9, 135.5, 118.3, 127.5, 109.9, 108.8, 137.6, 137.9, 114.0, 137.6, 98.3, 94.8, 112.9, 126.4, 134.6, 117.7, 110.2, 110.0, 134.2, 139.0, 111.8, 130.7, 98.9, 85.9, 107.8, 129.2, 117.9, 114.1, 109.8, 94.1, 124.7, 140.0, 100.7, 127.0, 91.9, 83.6, 114.8, 121.2, 113.7, 119.6, 108.5, 100.2, 131.1, 132.8, 108.3, 121.8, 91.3, 84.1, 112.0, 125.7, 112.5, 112.4, 110.5, 101.4, 115.3, 125.9, 108.8, 127.6, 91.5, 80.8, 120.4, 104.5, 115.8, 110.9, 101.0, 93.4, 121.3, 122.2, 101.1, 120.1, 85.2, 74.7, 99.9, 105.2, 109.0, 108.5, 100.3, 90.3, 110.6, 119.0, 103.0, 116.4, 88.3, 73.3, 99.5, 106.9, 111.4, 101.5, 98.4, 96.7, 96.5, 117.6, 101.9, 115.0, 87.0, 74.6, 94.0, 108.2, 104.1, 105.5, 101.9, 86.9, 109.6, 119.1, 91.0, 118.0, 85.6, 74.9, 96.1, 107.4, 109.5, 109.8, 109.1, 89.9, 100.3, 133.5, 104.0, 125.2, 88.1, 75.1, 103.5, 109.2, 110.9, 111.3, 106.4, 95.4, 113.5, 115.5, 105.6, 121.5, 90.0, 76.6, 99.2, 112.9, 110.2, 112.7, 105.4, 98.2, 109.0, 118.3, 109.5, 120.2, 87.2, 79.3, 96.5, 110.0, 109.5, 113.4, 105.5, 95.6, 109.2, 121.2, 109.2, 123.1, 86.5, 77.5, 51.4, 47.5, 81.8, 100.6, 104.0, 89.7, 101.4, 99.6, 86.3, 67.6, 33.8, 35.4, 73.0]
# [41.2, 55.0, 52.8, 47.1, 42.5, 41.9, 36.3, 42.1, 49.9, 49.2, 45.0, 44.5, 46.4, 45.0, 50.7, 45.2, 49.4, 48.1, 45.5, 48.4, 46.9, 50.3, 51.7, 47.4, 49.0, 47.4, 51.3, 48.6, 51.4, 54.4, 51.3, 51.9, 51.7, 57.7, 57.9, 54.4, 57.2, 52.9, 52.3, 55.4, 54.6, 53.6, 54.5, 50.6, 56.4, 55.4, 57.7, 62.0, 57.8, 53.8, 56.2, 53.9, 54.1, 56.1, 56.3, 46.3, 54.9, 60.3, 63.0, 66.7, 60.2, 58.6, 66.4, 64.2, 61.6, 66.5, 59.5, 62.4, 65.2, 63.9, 71.8, 74.4, 66.2, 58.9, 65.1, 63.4, 65.3, 63.5, 62.8, 64.7, 65.4, 63.0, 74.1, 73.5, 72.7, 65.6, 68.5, 65.9, 70.5, 70.1, 70.4, 66.4, 70.4, 73.8, 78.2, 79.2, 76.8, 67.8, 72.4, 73.9, 77.7, 75.8, 80.1, 73.9, 78.5, 81.6, 84.2, 95.5, 83.6, 74.7, 80.8, 83.8, 84.9, 83.7, 86.3, 82.9, 87.0, 90.5, 93.5, 109.7, 91.8, 82.6, 93.3, 93.5, 92.1, 99.9, 99.9, 94.3, 103.7, 103.7, 114.1, 131.2, 107.8, 100.6, 112.4, 109.4, 112.0, 119.2, 115.4, 113.9, 116.5, 121.4, 141.1, 152.3, 126.2, 116.5, 126.7, 122.9, 136.4, 137.5, 137.4, 133.5, 139.2, 142.2, 166.4, 177.3, 150.6, 131.3, 149.3, 145.4, 153.1, 157.4, 157.0, 150.2, 149.7, 162.0, 187.0, 187.8, 165.5, 146.6, 166.6, 163.8, 177.5, 171.9, 178.5, 167.0, 175.4, 179.6, 207.1, 223.9, 185.2, 167.6, 202.6, 228.8, 236.9, 232.0, 220.4, 212.7, 220.3, 242.8, 284.3, 300.0, 276.4, 255.7, 297.3]

# %%
# Do not modify the code in this cell.
import matplotlib.pyplot as plt
# %matplotlib inline

try:
    fig, ax = plt.subplots(figsize=(16, 9))
    ax.plot(months, clothing_stores_revenue, label="Clothing stores' revenue")
    ax.plot(months, mail_order_revenue, label="Mail order companies' revenue")
    ax.set_xlabel('Date')
    ax.set_ylabel('Percent, 2015=100')
    ax.legend()
    plt.show()
except Exception as e:
    print('There was an error creating the plot.\n'
          'Check if your lists are correctly named and assembled.\n'
          "Here's your error, for your debugging pleasure.")
    raise e

# %% [markdown]
# **8. How do the two branches compare? Discuss any yearly cycles you observe, as well as long-term developments. Also explain why you think these patterns are there. Pretend you are writing this to your supervisor or a client who asked you to analyze this dataset.**
#
# Stijgende lijn in online aankopen betekent dat mensen steeds meer online aankopen doen. Jaarlijks is er ook een piek te zien wat waarschijnlijk met de feestdagen in november/december te maken heeft.  Corona heeft er tevens voor gezorgd dat er een flinke groei is ontstaan bij online aankopen voor 2020/2021.
#
# Bij het segment kleding is de aankoop gelinkt aan het seizoen, je ziet dipjes en uitschieters door de jaren heen. Daarnaast ziet het er redelijk stabel uit (hoewel de laatste jaren er iets minder kleding is afgenomen door de consument). Je ziet wel dat Corona voor een dip in aankopen heeft gezorgd, daar de omzet achter blijft.

# %% [markdown]
# ## 3. Computing With Data
#
# ### 3.1 Year Over Year Change
#
# Let's take a closer look at these two branches of retail: clothing stores and mail order companies. A commonly used metric in business is the year-over-year revenue change. It is computed like so:
#
# $$\text{YoY}_\text{month} = \frac{\text{Revenue}_\text{month}}{\text{Revenue}_\text{same month last year}} \times 100$$
#
# Search the web for a longer explanation of this term if you'd like one.
#
# **9. Why should we compare revenue for a particular month to the revenue of that same month, one year ago?**
#
# Het geeft een nauwkeuriger beeld om het met een jaar daarvoor te vergelijken, je hebt geen ''last'' van seizoensinvloeden en feestdagen t.o.v. het vergelijken van maanden met elkaar. Daarnaast kun je meten hoe je omzet zich verhoud t.o.v. het voorgaande jaar (groei of daling). Bijvoorbeeld de groei van pakketdiensten in november/december vergelijken met het jaar daarvoor.
#
# **10. In the code cell below, compute the year-over-year revenue change for every month, for both branches of the retail sector, each in their own new list. Skip the first year (why?). Put an `x` in the checkboxes when you're ready. Run the next cell to see a new plot for your data.**
#
# - [x] Clothing stores $\Longrightarrow$ `clothing_stores_yoy`
# - [x] Mail order companies $\Longrightarrow$ `mail_order_yoy`

# %%
clothing_stores_yoy = list()
mail_order_yoy = list()

for i in range(len(months[12:])):
  yoy_clothingStores = (clothing_stores_revenue[i+12] / clothing_stores_revenue[i])*100
  clothing_stores_yoy.append(yoy_clothingStores)
  
  yoy_mailOrder = (mail_order_revenue[i+12] / mail_order_revenue[i])*100
  mail_order_yoy.append(yoy_mailOrder)

# %%
try:
    fig, ax = plt.subplots(figsize=(16, 9))
    ax.plot(months[12:], clothing_stores_yoy, label="Clothing stores' YoY")
    ax.plot(months[12:], mail_order_yoy, label="Mail order companies' YoY")
    ax.set_xlabel('Date')
    ax.set_ylabel('YoY change, 2015=100')
    ax.legend()
    plt.show()
except Exception as e:
    print('There was an error creating the plot.\n'
          'Check if your lists are correctly named and assembled.\n'
          "Here's your error, for your debugging pleasure.")
    raise e

# %% [markdown]
# **11. In the code cell below, find the best and worst months for both branches of the retail sector in terms of year-over-year revenue change. Print the branch, month and YoY in a nice and tidy way.**

# %%
clothing_stores_max_yoy = max(clothing_stores_yoy)
clothing_stores_min_yoy = min(clothing_stores_yoy)
clothing_stores_max_yoy_month = months[clothing_stores_yoy.index(clothing_stores_max_yoy) + 12]
clothing_stores_min_yoy_month = months[clothing_stores_yoy.index(clothing_stores_min_yoy) + 12]

mail_order_max_yoy = max(mail_order_yoy)
mail_order_min_yoy = min(mail_order_yoy)
mail_order_max_yoy_month = months[mail_order_yoy.index(mail_order_max_yoy) + 12]
mail_order_min_yoy_month = months[mail_order_yoy.index(mail_order_min_yoy) + 12]

print('Clothing stores best ', clothing_stores_max_yoy_month.strftime('%Y %B'), "YoY = {:.2f}%".format(clothing_stores_max_yoy))
print('Clothing stores worst ', clothing_stores_min_yoy_month.strftime('%Y %B,'), "YoY = {:.2f}%".format(clothing_stores_min_yoy))
print('Mail order companies best ', mail_order_max_yoy_month.strftime('%Y %B,'), "YoY = {:.2f}%".format(mail_order_max_yoy))
print('Mail order companies worst ', mail_order_min_yoy_month.strftime('%Y %B,'), "YoY = {:.2f}%".format(mail_order_min_yoy))
# Out:
# Clothing stores best  2021 maart YoY = 142.02%
# Clothing stores worst  2021 januari, YoY = 39.08%
# Mail order companies best  2021 februari, YoY = 152.57%
# Mail order companies worst  2006 februari, YoY = 81.82%

# %% [markdown]
# ### 3.2 Similarity Between Branches
#
# We've seen that the pattern for revenue is quite different for clothing stores and mail order companies. In other words: their revenues don't move up or down together. A way to make this observation more specific is to compute the **correlation coefficient**. It is a number between $-1$ and $1$ that describes the relation between two *random variables*. Here is how it works applied to our revenue numbers:
#
# - If the correlation coefficient for the revenue of two branches of the retail sector is $1$, their revenue is *positively correlated*. This means that when the revenue of branch A goes up, the revenue of branch B also goes up. In other words: the revenues for both branches go up together.
# - If the correlation coefficient is $-1$, the revenues of the two branches are *negatively correlated*. This means that if A's revenue goes up, B's revenue goes down. Similarly, if B's revenue goes up, A's revenue goes down. They move in the exact opposite direction.
# - If the correlation coefficient is $0$, there is no clear pattern between the revenues of both branches.
#
# Here's a table that summarizes this information:
#
# | Correlation coefficient | Meaning                              |
# |-------------------------|--------------------------------------|
# | $1$                     | Revenues go up together              |
# | $0$                     | No pattern                           |
# | $-1$                    | Revenues move in opposite directions |
#
# Note that there is a continuous scale between $-1$ and $1$! A correlation coefficient of $0.3$ indicates a somewhat positively correlated relationship.
#
# And here's an image that visualizes the correlation coefficient.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/d/d4/Correlation_examples2.svg"/>
#
# We've provided a function `corrcoef` that computes the correlation coefficient for two lists.
#
# **11. In the code cell below, use the function `corrcoef` to compute the correlation coefficient for each pair of branches in our dataset. Then print a sorted table that shows each unique pair and their correlation coefficients. You can take inspiration from this table (but it doesn't have to look exactly like it):**
#
# ```
# Coeff   Branch A                                          Branch B
# ===========================================================================================================
# 0.98    4711, 472 Winkels in voedingsmiddelen             4711 Supermarkten
# 0.91    475 Winkels in overige huishoudwaren              4752 Winkels in doe-het-zelfartikelen
# 0.91    47528 Bouwmarkten                                 4752 Winkels in doe-het-zelfartikelen
# ```

# %%
import numpy as np

def corrcoef(branch_a, branch_b):
    return np.corrcoef(branch_a, branch_b)[0, 1]
  
unique_list = []
for row in range(len(NewData2)):
    if NewData2[row]['Branches'] in unique_list:
        continue
    else:
        unique_list.append(NewData2[row]['Branches'])

def get_data(NewData2, branch_name):
    branch_index_values = []
    for x in range(len(NewData2)):
        if branch_name in NewData2[x]['Branches']and len(branch_name)==len(NewData2[x]['Branches']):
            branch_index_values.append(NewData2[x]['TurnoverValue'])
    return branch_index_values

def corrcoef(branch_a, branch_b):
    return np.corrcoef(branch_a, branch_b)[0, 1]

space_1=14
space_2=50

print(("Coeff")+(" "*9)+("Branch A")+(" "*42)+("Branch B"))
print("="*120)
corrcoef_list = []
for x in range(len(unique_list)):
    for y in range(x+1, len(unique_list)):
        branch_a = get_data(NewData2, unique_list[x])
        branch_b = get_data(NewData2, unique_list[y])
        corr_data = round(corrcoef(branch_a, branch_b),3)
        corrcoef_list.append([corr_data, unique_list[x], unique_list[y]])
    
        space_A=" "*(space_1-len(str(corr_data)))
        space_B=" "*(space_2-len(str(unique_list[x])))
        
        print(str(corr_data)+space_A+str(unique_list[x])+space_B+str(unique_list[y]))
# Out:
# Coeff         Branch A                                          Branch B
# ========================================================================================================================
# 0.984         4711, 472 Winkels in voedingsmiddelen             4711 Supermarkten
# 0.077         4711, 472 Winkels in voedingsmiddelen             4719, 474-477 Winkels in non-foodart.
# 0.174         4711, 472 Winkels in voedingsmiddelen             472 Winkels in voedingsmiddelen
# -0.201        4711, 472 Winkels in voedingsmiddelen             474 Winkels in consumentenelektronica
# -0.041        4711, 472 Winkels in voedingsmiddelen             475 Winkels in overige huishoudwaren
# 0.211         4711, 472 Winkels in voedingsmiddelen             Winkels in meubels, woninginrichting alg
# 0.066         4711, 472 Winkels in voedingsmiddelen             4752 Winkels in doe-het-zelfartikelen
# 0.103         4711, 472 Winkels in voedingsmiddelen             47528 Bouwmarkten
# -0.054        4711, 472 Winkels in voedingsmiddelen             4759 Winkels overige huishoudartikelen
# -0.279        4711, 472 Winkels in voedingsmiddelen             476 Winkels in recreatieartikelen
# -0.334        4711, 472 Winkels in voedingsmiddelen             4765 Speelgoedwinkels
# -0.102        4711, 472 Winkels in voedingsmiddelen             4771 Winkels in kleding
# -0.36         4711, 472 Winkels in voedingsmiddelen             4772 Winkels in schoenen en lederwaren
# 0.859         4711, 472 Winkels in voedingsmiddelen             47741 Drogisterijen
# 0.84          4711, 472 Winkels in voedingsmiddelen             4791 Postorderbedrijven, webwinkels
# -0.066        4711 Supermarkten                                 4719, 474-477 Winkels in non-foodart.
# -0.003        4711 Supermarkten                                 472 Winkels in voedingsmiddelen
# -0.332        4711 Supermarkten                                 474 Winkels in consumentenelektronica
# -0.159        4711 Supermarkten                                 475 Winkels in overige huishoudwaren
# 0.129         4711 Supermarkten                                 Winkels in meubels, woninginrichting alg
# -0.016        4711 Supermarkten                                 4752 Winkels in doe-het-zelfartikelen
# 0.036         4711 Supermarkten                                 47528 Bouwmarkten
# -0.185        4711 Supermarkten                                 4759 Winkels overige huishoudartikelen
# -0.399        4711 Supermarkten                                 476 Winkels in recreatieartikelen
# -0.427        4711 Supermarkten                                 4765 Speelgoedwinkels
# -0.196        4711 Supermarkten                                 4771 Winkels in kleding
# -0.441        4711 Supermarkten                                 4772 Winkels in schoenen en lederwaren
# 0.788         4711 Supermarkten                                 47741 Drogisterijen
# 0.912         475 Winkels in overige huishoudwaren              4752 Winkels in doe-het-zelfartikelen
# 0.799         475 Winkels in overige huishoudwaren              47528 Bouwmarkten
# 0.887         475 Winkels in overige huishoudwaren              4759 Winkels overige huishoudartikelen
# 0.684         475 Winkels in overige huishoudwaren              476 Winkels in recreatieartikelen
# 0.267         475 Winkels in overige huishoudwaren              4765 Speelgoedwinkels
# 0.479         475 Winkels in overige huishoudwaren              4771 Winkels in kleding
# 0.422         475 Winkels in overige huishoudwaren              4772 Winkels in schoenen en lederwaren
# 0.145         475 Winkels in overige huishoudwaren              47741 Drogisterijen
# -0.077        475 Winkels in overige huishoudwaren              4791 Postorderbedrijven, webwinkels
# 0.706         Winkels in meubels, woninginrichting alg          4752 Winkels in doe-het-zelfartikelen
# 0.573         Winkels in meubels, woninginrichting alg          47528 Bouwmarkten
# 0.84          Winkels in meubels, woninginrichting alg          4759 Winkels overige huishoudartikelen
# 0.335         Winkels in meubels, woninginrichting alg          476 Winkels in recreatieartikelen
# 0.057         Winkels in meubels, woninginrichting alg          4765 Speelgoedwinkels
# 0.292         Winkels in meubels, woninginrichting alg          4771 Winkels in kleding
# 0.067         Winkels in meubels, woninginrichting alg          4772 Winkels in schoenen en lederwaren
# 0.293         Winkels in meubels, woninginrichting alg          47741 Drogisterijen
# 0.266         Winkels in meubels, woninginrichting alg          4791 Postorderbedrijven, webwinkels
# 0.907         4752 Winkels in doe-het-zelfartikelen             47528 Bouwmarkten
# 0.626         4752 Winkels in doe-het-zelfartikelen             4759 Winkels overige huishoudartikelen
# 0.525         4752 Winkels in doe-het-zelfartikelen             476 Winkels in recreatieartikelen
# -0.026        4752 Winkels in doe-het-zelfartikelen             4765 Speelgoedwinkels
# 0.33          4752 Winkels in doe-het-zelfartikelen             4771 Winkels in kleding
# 0.313         4752 Winkels in doe-het-zelfartikelen             4772 Winkels in schoenen en lederwaren
# 0.156         4752 Winkels in doe-het-zelfartikelen             47741 Drogisterijen
# 0.094         4752 Winkels in doe-het-zelfartikelen             4791 Postorderbedrijven, webwinkels
# 0.53          47528 Bouwmarkten                                 4759 Winkels overige huishoudartikelen
# 0.565         47528 Bouwmarkten                                 476 Winkels in recreatieartikelen
# -0.063        47528 Bouwmarkten                                 4765 Speelgoedwinkels
# 0.369         47528 Bouwmarkten                                 4771 Winkels in kleding
# 0.359         47528 Bouwmarkten                                 4772 Winkels in schoenen en lederwaren
# 0.163         47528 Bouwmarkten                                 47741 Drogisterijen
# 0.017         47528 Bouwmarkten                                 4791 Postorderbedrijven, webwinkels
# 0.689         4759 Winkels overige huishoudartikelen            476 Winkels in recreatieartikelen
# 0.508         4759 Winkels overige huishoudartikelen            4765 Speelgoedwinkels
# 0.552         4759 Winkels overige huishoudartikelen            4771 Winkels in kleding
# 0.422         4759 Winkels overige huishoudartikelen            4772 Winkels in schoenen en lederwaren
# 0.177         4759 Winkels overige huishoudartikelen            47741 Drogisterijen
# -0.169        4759 Winkels overige huishoudartikelen            4791 Postorderbedrijven, webwinkels
# 0.645         476 Winkels in recreatieartikelen                 4765 Speelgoedwinkels
# 0.652         476 Winkels in recreatieartikelen                 4771 Winkels in kleding
# 0.719         476 Winkels in recreatieartikelen                 4772 Winkels in schoenen en lederwaren
# 0.01          476 Winkels in recreatieartikelen                 47741 Drogisterijen
# -0.542        476 Winkels in recreatieartikelen                 4791 Postorderbedrijven, webwinkels
# 0.528         4765 Speelgoedwinkels                             4771 Winkels in kleding
# 0.515         4765 Speelgoedwinkels                             4772 Winkels in schoenen en lederwaren
# -0.067        4765 Speelgoedwinkels                             47741 Drogisterijen
# -0.56         4765 Speelgoedwinkels                             4791 Postorderbedrijven, webwinkels
# 0.873         4771 Winkels in kleding                           4772 Winkels in schoenen en lederwaren
# 0.07          4771 Winkels in kleding                           47741 Drogisterijen
# -0.404        4771 Winkels in kleding                           4791 Postorderbedrijven, webwinkels
# -0.185        4772 Winkels in schoenen en lederwaren            47741 Drogisterijen
# -0.614        4772 Winkels in schoenen en lederwaren            4791 Postorderbedrijven, webwinkels
# 0.655         47741 Drogisterijen                               4791 Postorderbedrijven, webwinkels

# %% [markdown]
# **12. Pick two correlation coefficients from the table you created and explain why you think these values are the way that they are. Be sure to pick two coefficients that are not close to each other.**
#
# #Correlatie geeft de mate van samenhang tussen twee variabelen weer, ofwel in hoeverre twee variabelen elkaar beïnvloeden. De correlatie wordt uitgedrukt in de correlatiecoëfficiënt. De waarde van de correlatiecoëfficiënt ligt altijd tussen -1 en +1.
#
# 0.873         4771 Winkels in kleding                           4772 Winkels in schoenen en lederwaren
# De correlatiecoëfficiënt is hoog/sterk omdat er vergelijkbare producten worden verkocht.
#
# -0.363        474 Winkels in consumentenelektronica             4791 Postorderbedrijven, webwinkels
# De correlatiecoëfficiënt is laag/zwak omdat winkels in consumentenelektronica voornamelijk consumentenelektronica verkopen. Terwijl webwinkels heel uitlopend/breed kunnen zijn.
# Dit geldt ook voor het volgende, hier is een zwakke correlatiecoëfficiënt ;
# -0.542        476 Winkels in recreatieartikelen                 4791 Postorderbedrijven, webwinkels
#
# -0.026        4752 Winkels in doe-het-zelfartikelen             4765 Speelgoedwinkels
# Er is hier nauwelijks of zelfs geen sprake van correlatie. In een speelgoedwinkel kan wel ''gereedschap'' verkocht worden maar dit is dan in de vorm van speelgoed. Andersom kun je uiteraard wel eens tegenkomen, dit is wellicht iets waarschijnlijker.
#
#
# **13. Imagine you are a very risk-aveestor shaping your portfolio of investments in the retail sector. How would you use the information in the table you created to minimize your investment risk? Which two branches of the retail sector would you invest in if you had to pick two? Use the correlation coefficient in your answer.**
#
# Indien ik risico's wil vermijden dan zou ik kiezen voor :
# -0.026        4752 Winkels in doe-het-zelfartikelen             4765 Speelgoedwinkels
# Dit i.v.m. het feit dat er nauwelijks tot geen correlatie bestaat. Mocht het in de ene branche minder gaan dan dan heb je altijd nog de stabiliteit van de andere branche. En vice versa. Zo speel je m.i. altijd safe.

# %% [markdown]
# ## 4. Conclusion
#
# You made it! This was the Retail assignment. Before you hand it in: restart the kernel and run all the cells. Then save it to GitHub and share the link with us in the usual way.
